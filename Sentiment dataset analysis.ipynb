# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install pandas numpy matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# load dataset 
data = pd.read_csv(r"C:\Users\revan\Downloads\Sentiment dataset.csv")

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
# Summary statistics for numerical columns
summary_stats = data.describe()
print("Summary Statistics:")
print(summary_stats)
# Out:
# Summary Statistics:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# ...

# %%
# Check for missing values
missing_values = data.isnull().sum()
print("\nMissing Values:")
print(missing_values)
# Out:
# Missing Values:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
# Visualize the distribution of the 'Sentiment' column
plt.figure(figsize=(10, 6))
sns.countplot(x='Sentiment', data=data, palette='viridis')
plt.title('Distribution of Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_10416\3425428503.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment', data=data, palette='viridis')

# %%
# Visualize the distribution of 'Likes' using a histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['Likes'], bins=30, kde=True, color='blue')
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualize the distribution of 'Retweets' using a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=data['Retweets'], color='orange')
plt.title('Box Plot of Retweets')
plt.xlabel('Retweets')
plt.show()

# %%
# Scatter plot to visualize the relationship between 'Likes' and 'Retweets'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Likes', y='Retweets', data=data, hue='Sentiment', palette='viridis')
plt.title('Scatter Plot: Likes vs Retweets')
plt.xlabel('Likes')
plt.ylabel('Retweets')
plt.show()

# %%
# Correlation matrix for numerical features
numerical_features = data.select_dtypes(include=[np.number])
correlation_matrix = numerical_features.corr()

# %%
# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Generate a report summarizing insights from the EDA
print("\nEDA Insights:")
print("1. The dataset contains a mix of positive, negative, and neutral sentiments.")
print("2. The 'Likes' and 'Retweets' columns show a positive correlation, indicating that posts with more likes tend to have more retweets.")
print("3. The distribution of 'Likes' is right-skewed, with most posts having a lower number of likes.")
print("4. The box plot of 'Retweets' shows some outliers, indicating a few posts with significantly higher retweets.")
print("5. The correlation matrix suggests that 'Likes' and 'Retweets' are moderately correlated.")
# Out:
# EDA Insights:
# 1. The dataset contains a mix of positive, negative, and neutral sentiments.
# 2. The 'Likes' and 'Retweets' columns show a positive correlation, indicating that posts with more likes tend to have more retweets.
# 3. The distribution of 'Likes' is right-skewed, with most posts having a lower number of likes.
# 4. The box plot of 'Retweets' shows some outliers, indicating a few posts with significantly higher retweets.
# 5. The correlation matrix suggests that 'Likes' and 'Retweets' are moderately correlated.
